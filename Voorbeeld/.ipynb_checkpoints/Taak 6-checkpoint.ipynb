# %%
import pandas as pd

# %%
data = pd.read_csv('Data.csv')

# %%
data
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie   None    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
data["Country"].unique() #Number of unique Countries, Catagorical analyses on number of goalscorers per country
# Out:
# array(['Spain', 'Italy', 'Germany', 'England', 'Brazil', 'France', 'USA',
#        'Portugal ', ' Netherlands'], dtype=object)

# %%
data["League"].unique()
# Out:
# array(['La Liga', 'Serie A', 'Bundesliga', 'Premier League',
#        'Campeonato Brasileiro S̩rie A', 'France Ligue 11',
#        'France Ligue 20', 'France Ligue 2', 'France Ligue 12',
#        'France Ligue 9', 'France Ligue 15', 'France Ligue 6',
#        'France Ligue 3', 'France Ligue 16', 'France Ligue 14',
#        'France Ligue 4', 'France Ligue 1', 'France Ligue 10',
#        'France Ligue 7', 'France Ligue 13', 'France Ligue 8',
#        'France Ligue 5', 'France Ligue 19', 'France Ligue 18',
#        'France Ligue 17', 'MLS', 'Primeira Liga', 'Eredivisie'],
#       dtype=object)

# %%
data["Player Names"].unique()
# Out:
# array(['Juanmi Callejon', 'Antoine Griezmann', 'Luis Suarez',
#        'Ruben Castro', 'Kevin Gameiro', 'Cristiano Ronaldo',
#        'Karim Benzema', 'Neymar ', 'Iago Aspas', 'Sergi Enrich',
#        'Aduriz ', 'Sandro Ramlrez', 'Lionel Messi', 'Gerard Moreno',
#        'Morata', 'Wissam Ben Yedder', 'Willian Jose', 'Andone ',
#        'Cedric Bakambu', 'Isco', 'Mohamed Salah', 'Gregoire Defrel',
#        'Ciro Immobile', 'Nikola Kalinic', 'Dries Mertens',
#        'Alejandro Gomez', 'Jose CallejOn', 'Iago Falque',
#        'Giovanni Simeone', 'Mauro Icardi', 'Diego Falcinelli',
#        'Cyril Thereau', 'Edin Dzeko', 'Lorenzo Insigne',
#        'Fabio Quagliarella', 'Borriello ', 'Carlos Bacca',
#        'Gonzalo Higuain', 'Keita Balde', 'Andrea Belotti', 'Fin Bartels',
#        'Lars Stindl', 'Serge Gnabry', 'Wagner ', 'Andrej Kramaric',
#        'Florian Niederlechner', 'Robert Lewandowski', 'Emil Forsberg',
# ...

# %%
data["League"].value_counts().plot(kind='bar') #Number of goalscorers per league, Catagorical analyses on number of goalscorers per league
# Out:
# <AxesSubplot:>

# %%
data["Player Names"].value_counts().plot(kind='pie') #Number of unique Countries, Catagorical analyses on number of goalscorers per country in a graph
# Out:
# <AxesSubplot:ylabel='Player Names'>
# C:\Users\Xin20\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data["Country"].value_counts().plot(kind='bar')

# %%
data
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie   None    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
data["Goals"].min() #Minimum of Goals
# Out:
# 2

# %%
data["Goals"].max() #Maximum of Goals
# Out:
# 37

# %%
data["Goals"].mean() #Mean of Goals
# Out:
# 11.784848484848485

# %%
data["Goals"].median()#Median of Goals
# Out:
# 11.0

# %%
data["Goals"].std() #Standard deviation of Goals
# Out:
# 5.982453920317568

# %%
data["Goals"].plot(kind='box') #BoxPlot
# Out:
# <AxesSubplot:>

# %%
newGoals = data[(data["Goals"] < 24)]
newGoals["Goals"].plot(kind='box') #BoxPlot
# Out:
# <AxesSubplot:>

# %%
data["Goals"].plot(kind='hist', bins = 40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data["xG"].min() #Lowest xg
# Out:
# 0.71

# %%
data["xG"].max() #Highest xg
# Out:
# 32.54

# %%
data["xG"].mean() #Mean of xg
# Out:
# 10.089606060606062

# %%
data["xG"].median() #Median of xg
# Out:
# 9.285

# %%
data["xG"].std() #Standard deviation of xG
# Out:
# 5.724843670305079

# %%
data["xG"].plot(kind='box') #BoxPlot, There are outliers present
# Out:
# <AxesSubplot:>

# %%
new = data[(data["xG"] < 22)];

new["xG"].plot(kind='box') #BoxPlot, Without outliers
# Out:
# <AxesSubplot:>

# %%
data["xG"].plot(kind='hist', bins = 30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data["Shots Per Avg Match"].min() #Minimum average amount of shots per game
# Out:
# 0.8

# %%
data["Shots Per Avg Match"].max() # Maximum average amount of shots per game
# Out:
# 7.2

# %%
data["Shots Per Avg Match"].mean() #mean of average shots per match
# Out:
# 2.948015151515152

# %%
data["Shots Per Avg Match"].median() #Median of average shots per match
# Out:
# 2.8449999999999998

# %%
data["Shots Per Avg Match"].std() #Standard deviation of average shots per match
# Out:
# 0.9149064811604102

# %%
data["Shots Per Avg Match"].plot(kind='hist', bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data["Shots Per Avg Match"].plot(kind='box') #BoxPlot, There are outliers present
# Out:
# <AxesSubplot:>

# %%
new2 = data[(data["Shots Per Avg Match"] < 4.9)]
new2["Shots Per Avg Match"].plot(kind='box') #without outliers
# Out:
# <AxesSubplot:>
