# %%
# "Portfolio assignment 7 
# 15 min: Look at the histogram of at least 2 columns with numerical data in the dataset that you chose in portfolio assignment 4.
# Do you recognise the distribution? 
# Does it look like a uniform or normal distribution or something else? 
# If it doesn't look like a uniform or normal distribution, 
# take a quick look here to see if you can find the distribution shape: 
# https://www.itl.nist.gov/div898/handbook/eda/section3/eda366.htm

# %%
import pandas as pd

# %%
data = pd.read_csv('Data.csv')

# %%
data
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie   None    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
#Numerical

# %%
data["Goals"].plot(kind='hist', bins = 40) # Goals
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Dit is een histogram voor de aantal doelpunten die iedere speler heeft gemaakt.
# De distributie van deze histogram heeft een Lognormal Distribution.
# Wat ik uit de histogram kan halen, is dat de piek van de histogram in het begin een hoge y-waarde heeften het snel omhoog gaat. 
# Vanaf de piek daalt het snel, maar de daling wordt naarmate het eind minder steil.
# Daarom is de de distributie een Lognormaal.

# %%
data["Shots Per Avg Match"].plot(kind='hist', bins = 100) # Shots Per Avg Match
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Dit is een histogram voor het gemiddelde aantal schoten een speler heeft gemaakt per wedstrijd heeft genomen.
# De distributie van deze histogram heeft een Binomial Distribution. 
# De piek van de histogram leunt meer links van centrum af. 
# Rechts van de piek daalt de frequentie minder snel naarmate de x-waarde omhoog gaat.
